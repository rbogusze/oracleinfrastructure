# %%
# this actually works fine for binary data

from kafka import KafkaConsumer

topics = 'remi_logs'
kafka_broker='192.168.1.161:9092'

# Just read from Kafka to file

consumer = KafkaConsumer(
    'remi_logs',
     bootstrap_servers=['192.168.1.161:9092'],
     auto_offset_reset='latest',
     enable_auto_commit=True,
     group_id='my-group',
)
   

consumer=KafkaConsumer(topics, bootstrap_servers=[kafka_broker], auto_offset_reset='latest')

# newFile = open("/Users/Remigiusz.Boguszewicz/tmp/from_kafka.file", "wb")


for msg in consumer:
    #print(msg.value)
    # write to file
    newFile = open("/Users/Remigiusz.Boguszewicz/tmp/from_kafka.file", "ab")
    newFile.write(bytes(msg.value))
    newFile.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-63bb06659afc> in <module>
#      20
#      21
# ---> 22 for msg in consumer:
#      23     #print(msg.value)
#      24     # write to file
#
# ~/opt/anaconda3/lib/python3.8/site-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
# ...

# %%
# read from Kafka but only between selected offsets

from kafka import KafkaConsumer
from kafka.structs import TopicPartition

topics = 'remi_logs'
kafka_broker='192.168.1.161:9092'

# Just read from Kafka to file

# consumer = KafkaConsumer(
#     'remi_logs',
#      bootstrap_servers=['192.168.1.161:9092'],
#      auto_offset_reset='latest',
#      enable_auto_commit=True,
#      group_id='my-group',
# )
   

# consumer=KafkaConsumer(topics, bootstrap_servers=[kafka_broker], auto_offset_reset='latest')
consumer=KafkaConsumer(bootstrap_servers=[kafka_broker])

# newFile = open("/Users/Remigiusz.Boguszewicz/tmp/from_kafka.file", "wb")

mypartition = TopicPartition(topics, 0)
consumer.assign([mypartition])


print(f"mypartition: {mypartition}")
consumer.seek(partition=mypartition, offset=10299)


for msg in consumer:
    print(msg.value)
    print(msg.offset)
    # write to file
    newFile = open("/Users/Remigiusz.Boguszewicz/tmp/from_kafka.file", "ab")
    newFile.write(bytes(msg.value))
    newFile.close()
    
    if msg.offset == 10299:
        print("Reached my end offset")
        break
# Out:
# mypartition: TopicPartition(topic='remi_logs', partition=0)
# b'* setup\nthis in .emacs\n\n\n  \n  \n\n\n  \n  \n  \n'
# 10299
# Reached my end offset
